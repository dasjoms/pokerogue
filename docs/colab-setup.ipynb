# %% [markdown]
# # PokéRogue Reinforcement Learning Setup
# This notebook installs all dependencies and runs the headless RL demo.

# %%
# Install system packages
# !apt-get update -y > /dev/null
# !apt-get install -y git curl build-essential python3 > /dev/null

# %%
# Clone the repository
# !git clone https://github.com/dasjoms/pokerogue.git
# %cd pokerogue

# %%
# Run setup script
# !bash setup.sh

# %%
# Activate Node via nvm
# %bash -c 'source ~/.nvm/nvm.sh && nvm use 22.14.0'

# %%
# Rebuild TensorFlow for current Node version
# %bash -c 'source ~/.nvm/nvm.sh && nvm use 22.14.0 && npm rebuild --build-from-source @tensorflow/tfjs-node'

# %%
# Verify environment
# !bash verify-setup.sh

# %%
# Run the DQN demonstration
# %bash -c 'source ~/.nvm/nvm.sh && nvm use 22.14.0 && VITE_HEADLESS=1 npx tsx scripts/rogue-env-dqn.ts'
